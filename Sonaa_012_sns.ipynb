# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-09901b4b-ac0a-4c03-9c08-6cffd7679ab2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09901b4b-ac0a-4c03-9c08-6cffd7679ab2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving market_fact.csv to market_fact.csv

# %%
sa =pd.read_csv("market_fact.csv")
sa.head()
# Out:
#      Ord_id  Prod_id   Ship_id  ...   Profit  Shipping_Cost  Product_Base_Margin
# 0  Ord_5446  Prod_16  SHP_7609  ...   -30.51           3.60                 0.56
# 1  Ord_5406  Prod_13  SHP_7549  ...     4.56           0.93                 0.54
# 2  Ord_5446   Prod_4  SHP_7610  ...  1148.90           2.50                 0.59
# 3  Ord_5456   Prod_6  SHP_7625  ...   729.34          14.30                 0.37
# 4  Ord_5485  Prod_17  SHP_7664  ...  1219.87          26.30                 0.38
#
# [5 rows x 10 columns]

# %%
sns.set_style("darkgrid")

# %%
sns.distplot(sa['Profit'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(sa['Shipping_Cost'])
plt.yscale('log')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(sa['Shipping_Cost'][:200], rug=True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(sa['Sales'], hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plt.subplot(2,2,1)
plt.title('Sales')
sns.distplot(sa['Sales'])

plt.subplot(2,2,2)
plt.title('Profit')
sns.distplot(sa['Profit'])

plt.subplot(2,2,3)
plt.title('Order_Quantity')
sns.distplot(sa['Order_Quantity'])

plt.subplot(2,2,4)
plt.title('Shipping_Cost')
sns.distplot(sa['Shipping_Cost'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(sa['Order_Quantity'])
plt.title('Order_Quantity')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(y=sa['Order_Quantity'])
plt.title('Order_Quantity')
plt.show()

# %%
sns.jointplot('Sales', 'Profit', sa)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sa = sa[(sa.Profit < 10000) & (sa.Sales < 20000)]
sns.jointplot('Sales','Profit' ,sa)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sa=pd.read_csv("market_fact.csv")
sa=sa[(sa.Profit <100) & (sa.Profit<-100) & (sa.Sales < 200)]
sns.jointplot('Sales','Profit',sa,kind='hex',color='k')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5f1f516c-2c07-4f2c-ae8e-2dd676bb0c26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f1f516c-2c07-4f2c-ae8e-2dd676bb0c26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bitcoin_price.csv to bitcoin_price.csv

# %%
from google.colab import files
uploaded = files.upload()


from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-51186278-8f84-45bb-805c-8f0b4042419a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51186278-8f84-45bb-805c-8f0b4042419a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ethereum_price.csv to ethereum_price.csv
#      <input type="file" id="files-bbfb199d-c848-45d8-8f43-e4b292ea1a7b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bbfb199d-c848-45d8-8f43-e4b292ea1a7b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving litecoin_price.csv to litecoin_price.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3ccb0089-62ff-46cd-a8e2-edb54bb052d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ccb0089-62ff-46cd-a8e2-edb54bb052d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving monero_price.csv to monero_price.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-35c5310c-ac98-437a-9e09-ebe9b6c4de09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35c5310c-ac98-437a-9e09-ebe9b6c4de09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving neo_price.csv to neo_price.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-df4f5e6d-758f-45fb-ba86-ab83fb913b27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df4f5e6d-758f-45fb-ba86-ab83fb913b27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving qtum_price.csv to qtum_price.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a1d97b49-6c41-4b03-8891-79e9e2aa9465" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1d97b49-6c41-4b03-8891-79e9e2aa9465">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ripple_price.csv to ripple_price.csv

# %%
btc = pd.read_csv("bitcoin_price.csv")
ether = pd.read_csv("ethereum_price.csv")
ltc = pd.read_csv("litecoin_price.csv")
monero = pd.read_csv("monero_price.csv")
neo = pd.read_csv("neo_price.csv")
quantum = pd.read_csv("qtum_price.csv")
ripple = pd.read_csv("ripple_price.csv")

btc.columns = btc.columns.map(lambda x: str(x) + '_btc')
ether.columns = ether.columns.map(lambda x: str(x) + '_et')
ltc.columns = ltc.columns.map(lambda x: str(x) + '_ltc')
monero.columns = monero.columns.map(lambda x: str(x) + '_mon')
neo.columns = neo.columns.map(lambda x: str(x) + '_neo')
quantum.columns = quantum.columns.map(lambda x: str(x) + '_qt')
ripple.columns = ripple.columns.map(lambda x: str(x) + '_rip')

btc.head()
# Out:
#        Date_btc  Open_btc  High_btc  ...  Close_btc     Volume_btc   Market Cap_btc
# 0  Nov 07, 2017   7023.10   7253.32  ...    7144.38  2,326,340,000  117,056,000,000
# 1  Nov 06, 2017   7403.22   7445.77  ...    7022.76  3,111,900,000  123,379,000,000
# 2  Nov 05, 2017   7404.52   7617.48  ...    7407.41  2,380,410,000  123,388,000,000
# 3  Nov 04, 2017   7164.48   7492.86  ...    7379.95  2,483,800,000  119,376,000,000
# 4  Nov 03, 2017   7087.53   7461.29  ...    7207.76  3,369,860,000  118,084,000,000
#
# [5 rows x 7 columns]

# %%
m1 = pd.merge(btc, ether, how="inner", left_on="Date_btc", right_on="Date_et")
m2 = pd.merge(m1, ltc, how="inner", left_on="Date_btc", right_on="Date_ltc")
m3 = pd.merge(m2, monero, how="inner", left_on="Date_btc", right_on="Date_mon")
m4 = pd.merge(m3, neo, how="inner", left_on="Date_btc", right_on="Date_neo")
m5 = pd.merge(m4, quantum, how="inner", left_on="Date_btc", right_on="Date_qt")
crypto = pd.merge(m5, ripple, how="inner", left_on="Date_btc", right_on="Date_rip")

crypto.head()
# Out:
#        Date_btc  Open_btc  High_btc  ...  Close_rip   Volume_rip Market Cap_rip
# 0  Nov 07, 2017   7023.10   7253.32  ...   0.210354  114,073,000  7,902,920,000
# 1  Nov 06, 2017   7403.22   7445.77  ...   0.205990  102,233,000  7,782,080,000
# 2  Nov 05, 2017   7404.52   7617.48  ...   0.202055   46,959,000  7,832,450,000
# 3  Nov 04, 2017   7164.48   7492.86  ...   0.203750   74,013,200  8,017,770,000
# 4  Nov 03, 2017   7087.53   7461.29  ...   0.208133  373,402,000  7,945,410,000
#
# [5 rows x 49 columns]

# %%
curr = crypto[["Close_btc", "Close_et", 'Close_ltc', "Close_mon", "Close_neo", "Close_qt"]]
curr.head()
# Out:
#    Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt
# 0    7144.38    294.66      61.30      99.76      26.23     11.21
# 1    7022.76    298.89      55.17     102.92      26.32     10.44
# 2    7407.41    296.26      54.75      86.35      26.38     10.13
# 3    7379.95    300.47      55.04      87.30      26.49     10.05
# 4    7207.76    305.71      56.18      87.99      26.82     10.38

# %%
sns.pairplot(curr)
plt.show()

# %%
plt.figure(figsize=(10,8))


sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %%
cor = curr.corr()
round(cor, 3)
# Out:
#            Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt
# Close_btc      1.000     0.449      0.658      0.697      0.735     0.382
# Close_et       0.449     1.000      0.490      0.539      0.482     0.791
# Close_ltc      0.658     0.490      1.000      0.793      0.641     0.448
# Close_mon      0.697     0.539      0.793      1.000      0.669     0.518
# Close_neo      0.735     0.482      0.641      0.669      1.000     0.557
# Close_qt       0.382     0.791      0.448      0.518      0.557     1.000
